# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.manifold
import sklearn.datasets
import glob
import sklearn.cluster
from PIL import Image

# %%
infectadas = glob.glob('Infectadas/*.png')
sanas = glob.glob('Sanas/*.png')

a = plt.imread(sanas[-10])
plt.imshow(np.mean(a,axis=2))

print(type(infectadas[0]))

target = []
imagenes = []
i=0

for archivo in sanas:
    image = Image.open(archivo)
    new_image = image.resize((100, 100))
    new_image.save('Sanas/'+str(i)+'.png')
    i+=1
    
# for archivo in sanas:
#     imagen = plt.imread(archivo)
#     dimensiones = np.shape(imagen)
#     if dimensiones[0] >= 105 and dimensiones[1] >= 105: #Descarta las que son demasiado pequeñas
#         imagen = np.mean(imagen[5:105,5:105],axis=2) #Cropea ligeramente las restantes, para dejarlas del mismo tamaño, cambia a monocromático
#         imagenes.append(imagen.reshape(10000))
#         target.append(0)
#         j+=1
# Out:
# <class 'str'>
